# %% [markdown]
# ### Preprocess tiles

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
# Background

# Some styles are ignored
images = [Image.open(f"original_data/BOOM Graphics/BGPattern 0{i+2}.png").convert("RGBA") for i in range(8)]
image = Image.fromarray(np.vstack(images))
image.save("boomgame/data/image/background.png")

plt.imshow(image)
plt.show()

# %%
# Border

images = [Image.open(f"original_data/BOOM Graphics/Border 0{i+1}.png").convert("RGBA") for i in range(8)]
image = Image.fromarray(np.vstack(images))
image.save("boomgame/data/image/border.png")

plt.imshow(image)
plt.show()

# %%
# Breakable

image = Image.open("original_data/BOOM Graphics/Breakable Blocks.png").convert("RGBA")
image.save("boomgame/data/image/breakable_wall.png")

plt.imshow(image)
plt.show()

# %%
# Solid

image = Image.open("original_data/BOOM Graphics/Fixed Blocks.png").convert("RGBA")
image = Image.fromarray(np.vstack(np.split(np.array(image), 8, axis = 1)))
image.save("boomgame/data/image/solid_wall.png")

plt.imshow(image)
plt.show()

# %%
# Player

void = np.array([[[255, 255, 255, 0]] * 32] * 32, dtype=np.uint8)

for i in range(2):
    image = Image.open(f"original_data/BOOM Graphics/Player{i+1}.png").convert("RGBA")
    line = np.hstack(np.split(np.array(image), 2) + [void] * 2)
    image = Image.fromarray(np.vstack(np.split(line, 5, axis = 1)))
    image.save(f"boomgame/data/image/player{i+1}.png")

    plt.imshow(image)
    plt.show()

# %%
# Bomb

image = Image.open("original_data/BOOM Graphics/Bomb.png")
image.save("boomgame/data/image/bomb.png")

plt.imshow(image)
plt.show()

# %%
# Laser

image = Image.open("original_data/BOOM Graphics/Explosion.png")
image.save("boomgame/data/image/laser.png")

plt.imshow(image)
plt.show()

# %%
# Teleporter

image = Image.open("original_data/BOOM Graphics/Teleporter.png")
image.save("boomgame/data/image/teleporter.png")

plt.imshow(image)
plt.show()

# %%
# Coin

image = Image.open("original_data/BOOM Graphics/Coin.png")
image.save("boomgame/data/image/coin.png")

plt.imshow(image)
plt.show()

# %%
# Flash

image = Image.open("original_data/BOOM Graphics/Flash.png")
image.save("boomgame/data/image/flash.png")

plt.imshow(image)
plt.show()

# %%
# Enemy

void = np.array([[[255, 255, 255, 0]] * 32] * 32, dtype=np.uint8)

for name in ["Soldier", "Sarge", "Lizzy", "Taur", "Gunner", "Thing", "Ghost", "Smoulder", "Skully", "Giggler"]:
    image = Image.open(f"original_data/BOOM Graphics/{name}.png").convert("RGBA")
    line = np.hstack(np.split(np.array(image), 2))
    n = line.shape[1] // 32
    if n%4:
        line = np.hstack([line] + (4 - (n%4)) * [void])

    image = Image.fromarray(np.vstack(np.split(line, 6, axis = 1)))
    image.save(f"boomgame/data/image/{name.lower()}.png")

    plt.imshow(image)
    plt.show()

# %%
# Alien

void = np.array([[[255, 255, 255, 0]] * 32] * 32, dtype=np.uint8)

image = Image.open("original_data/BOOM Graphics/Alien Frames.png").convert("RGBA")
line = np.hstack(np.split(np.array(image), 2))
n = line.shape[1] // 32
if n%4:
    line = np.hstack([line] + (4 - (n%4)) * [void])

image = Image.fromarray(np.vstack(np.split(line, 5, axis = 1)))
image.save("boomgame/data/image/alien.png")

plt.imshow(image)
plt.show()

# %%
# Bullet

void = np.array([[[255, 255, 255, 0]] * 32] * 32, dtype=np.uint8)

# Extracted by hand
bullet_rect = {
    "Shot": [(0, 0, 7, 7)] + [(0, 0, 26, 24)] * 4,
    "Fireball": [(0, 0, 13, 13)] + [(0, 0, 32, 32)] * 4,
    "MGShot": [(0, 0, 10, 7)] + [(1, 1, 21, 21)] * 5,
    "Lightbolt": [(0, 0, 13, 13)] + [(0, 0, 32, 32)] * 4,
    "Flame": [(0, 0, 13 + 4 * i, 32) for i in range(5)],
    "Plasma": [(0, 0, 13, 13)] + [(0, 0, 32, 32)] * 4,
    "Magma": [(0, 0, 26, 26)] + [(0, 0, 32, 32)] * 4,
}

for name in bullet_rect:
    image = np.array(Image.open(f"original_data/BOOM Graphics/{name}.png").convert("RGBA"))
    n = image.shape[1] // 32

    line = np.split(image, n, axis=1)
    if len(line) > 5 and not name == "Flame": # There is direction in images, not needed
        line = [line[0]] + line[4:]  # Down + explosion
    centered_images = []
    for image, (i, j, h, w) in zip(line, bullet_rect[name]):
        true_bullet = image[i: i + h, j: j + w]
        centered_image = void.copy()
        i = int(16 - h / 2)
        j = int(16 - w / 2)
        centered_image[i: i + h, j: j + w] = true_bullet
        centered_images.append(centered_image)

    image = np.hstack(centered_images)
    Image.fromarray(image).save(f"boomgame/data/image/{name.lower()}.png")

    plt.imshow(image)
    plt.show()

# %%
# Head Boss

image = Image.open("original_data/BOOM Graphics/Head Boss.png")
image.save("boomgame/data/image/head.png")

plt.imshow(image)
plt.show()

# %%
# Head Missile

rect = [(0, 0, 20, 20)] + [(0, 0, 18, 18)] + [(0, 0, 32, 32)] * 5
void = np.array([[[255, 255, 255, 0]] * 32] * 32, dtype=np.uint8)

image = np.array(Image.open("original_data/BOOM Graphics/Head Missile.png"))
n = image.shape[1] // 32

line = np.split(image, n, axis=1)

centered_images = []
for image, (i, j, h, w) in zip(line, rect):
    true_bullet = image[i: i + h, j: j + w]
    centered_image = void.copy()
    i = int(16 - h / 2)
    j = int(16 - w / 2)
    centered_image[i: i + h, j: j + w] = true_bullet
    centered_images.append(centered_image)

image = np.hstack(centered_images)
Image.fromarray(image).save("boomgame/data/image/missile.png")

plt.imshow(image)
plt.show()

# %%
# Panel

image = Image.open("original_data/BOOM Graphics/Panel.png")
image.save("boomgame/data/image/panel.png")
print(image.size, " -> ", image.size[0] // 32, ",", image.size[1] // 32)

plt.imshow(image)
plt.show()

# %%
# Player head

for i in range(2):
    image = Image.open(f"original_data/BOOM Graphics/Player {i+1} Head.png").convert("RGBA")
    image.save(f"boomgame/data/image/player_head{i+1}.png")
    print(image.size)

    plt.imshow(image)
    plt.show()

# %%
# Heart

image = Image.open("original_data/BOOM Graphics/Heart Icons.png").convert("RGBA")
np_image = np.array(image)[0:16]
image = Image.fromarray(np.hstack((np_image[:, 0:16], np_image[:, 18:34], np_image[:, 36:52])))  # Delete weird extra space
image.save("boomgame/data/image/heart.png")

plt.imshow(image)
plt.show()

# %%
# Extra icons

image = np.array(Image.open("original_data/BOOM Graphics/EXTRA Icons.png"))
images = np.split(image[0:13], 6, axis=1)
image = np.hstack([image[:, :13] for image in images])

Image.fromarray(image).save("boomgame/data/image/extra_icons.png")

plt.imshow(image)
plt.show()

# %%
# Bonus icons

image = np.array(Image.open("original_data/BOOM Graphics/Bonus Icons.png"))

images = np.split(image, 2)
image = np.vstack([image[:13, :] for image in images])

images = np.split(image, 5, axis=1)
image = np.hstack([image[:, :13] for image in images])

Image.fromarray(image).save("boomgame/data/image/bonus_icons.png")

plt.imshow(image)
plt.show()

# %%
# Extra letters

image = np.array(Image.open("original_data/BOOM Graphics/EXTRA Letters.png"))
image = np.hstack(np.split(image, 2))
image = np.vstack(np.split(image, 5, axis=1))

Image.fromarray(image).save("boomgame/data/image/extra_letters.png")

plt.imshow(image)
plt.show()

# %%
# Bonuses

image = Image.open("original_data/BOOM Graphics/Bonuses.png")
image.save("boomgame/data/image/bonuses.png")

plt.imshow(image)
plt.show()

# %%
# Shield

image = Image.open("original_data/BOOM Graphics/Shield.png").convert("RGBA")
image.save("boomgame/data/image/shield.png")

plt.imshow(image)
plt.show()

# %%
# Game over slider

image = Image.open("original_data/BOOM Graphics/Game Over.png").convert("RGBA")
image.save("boomgame/data/image/game_over.png")

plt.imshow(image)
plt.show()

# %%
# Hurry up slider

image = Image.open("original_data/BOOM Graphics/Hurry Up.png").convert("RGBA")
image.save("boomgame/data/image/hurry_up.png")

plt.imshow(image)
plt.show()

# %%
# Extra Game slider

image = Image.open("original_data/BOOM Graphics/EXTRA Game.png").convert("RGBA")
image.save("boomgame/data/image/extra_game.png")

plt.imshow(image)
plt.show()

# %%
# Game icon

image = Image.open("original_data/BOOM.icns").convert("RGBA")
image.save("boomgame/data/image/game_icon.png")

plt.imshow(image)
plt.show()

# %%
# Scores


#10-1K
image = Image.open("original_data/BOOM Graphics/Points 10-1K.png").convert("RGBA")
scores = np.split(np.array(image), 13, axis=1)
scores = list(map(Image.fromarray, scores))

score_values = [10, 50, 100, 150] + list(range(200, 1001, 100))

# 5K
scores.append(Image.open("original_data/BOOM Graphics/Points 5K.png").convert("RGBA"))
score_values.append(5000)

# 100K
scores.append(Image.open("original_data/BOOM Graphics/Points 100K.png").convert("RGBA"))
score_values.append(100000)

for score, value in zip(scores, score_values):
    score.save(f"boomgame/data/image/score_{value}.png")
    plt.xlim(0, 100)
    plt.ylim(30, 0)
    plt.imshow(score)
    plt.show()

# %%
# Extra Life

image = Image.open("original_data/BOOM Graphics/1_2Up.png").convert("RGBA")
extra_lifes = np.split(np.array(image), 2, axis=1)

for i, extra_life in enumerate(extra_lifes):
    Image.fromarray(extra_life).save(f"boomgame/data/image/extra_life_{i + 1}.png")
    plt.imshow(extra_life)
    plt.show()

# %%
# Loading screen

logo = Image.new("RGBA", (640, 480), (0, 0, 0, 255))
original_logo = Image.open("original_data/BOOM Graphics/Factor Software Logo.png").convert("RGBA")
logo.paste(original_logo, ((640 - original_logo.size[0]) // 2, (480 - original_logo.size[1]) // 2))
logo.save("boomgame/data/image/loading_logo.png")

plt.imshow(logo)
plt.show()

screen = Image.open("original_data/BOOM Graphics/Loading Screen.png").convert("RGBA")
screen.save("boomgame/data/image/loading_screen.png")

plt.imshow(screen)
plt.show()


bomb = Image.open("original_data/BOOM Graphics/Loading Bomb.png").convert("RGBA")
bomb.save("boomgame/data/image/loading_bomb_grey.png")

plt.imshow(screen)
plt.imshow(bomb)
plt.show()

bomb_array = np.array(bomb)
bomb_array[:,:,0] = 0
bomb_array[:,:,2] = 0

green_bomb = Image.fromarray(bomb_array)
green_bomb.save("boomgame/data/image/loading_bomb_green.png")

plt.imshow(green_bomb)
plt.show()

# %%
# Menu backgrounds

image = Image.open("original_data/BOOM Graphics/BGPattern 01.png").convert("RGBA")
image.save("boomgame/data/image/background_menu_1.png")

plt.imshow(image)
plt.show()

image = Image.open("original_data/BOOM Graphics/BGPattern 10.png").convert("RGBA")
image.save("boomgame/data/image/background_menu_2.png")

plt.imshow(image)
plt.show()

# %%
# Menu LOGO

image = Image.open("original_data/BOOM Graphics/BOOM Logo.png").convert("RGBA")
image.save("boomgame/data/image/BOOM.png")

plt.imshow(image)
plt.show()

# %% [markdown]
# ### Sounds

# %%
def copy(path_from, path_to):
    with open(path_from, "rb") as file_from, open(path_to, "wb") as file_to:
        file_to.write(file_from.read())

# %%
# Breakable wall

copy("original_data/BOOM Sounds/BlockDestruction.wav", "boomgame/data/sound/BreakableWallRemoving.wav")

# %%
# Coin

copy("original_data/BOOM Sounds/Coin.wav", "boomgame/data/sound/CoinRemoving.wav")

# %%
# Bomb

copy("original_data/BOOM Sounds/LightTheFuse.wav", "boomgame/data/sound/BombSpawn.wav")
copy("original_data/BOOM Sounds/Explosion.wav", "boomgame/data/sound/BombRemoving.wav")

# %%
# Bullet

bullets = [
    ("Shot", "Shot"),
    ("Fireball", "Fireball"),
    ("MGShot", "Pulse"),
    ("Lightbolt", "Bolt"),
    ("Flame", "Flame"),
    ("Plasma", "Plasma"),
    ("Magma", "Magma"),
    ("Missile", "HeadShot"),
]

for bullet_name, sound_name in bullets:
    copy(f"original_data/BOOM Sounds/{sound_name}.wav", f"boomgame/data/sound/{bullet_name}Spawn.wav")
    copy(f"original_data/BOOM Sounds/{sound_name}Hit.wav", f"boomgame/data/sound/{bullet_name}Removing.wav")

# %%
# Enemy

for name in ["Soldier", "Sarge", "Lizzy", "Taur", "Gunner", "Thing", "Ghost", "Smoulder", "Skully", "Giggler", "Head"]:
    copy(f"original_data/BOOM Sounds/{name}Noise.wav", f"boomgame/data/sound/{name}Noise.wav")
    copy(f"original_data/BOOM Sounds/{name}Death.wav", f"boomgame/data/sound/{name}Removing.wav")

# %%
# Alien

copy("original_data/BOOM Sounds/AlienDeath.wav", "boomgame/data/sound/AlienRemoving.wav")

# %%
# Player

for id_ in (1, 2):
    copy(f"original_data/BOOM Sounds/P{id_}Ouch.wav", f"boomgame/data/sound/Player{id_}Noise.wav")
    copy(f"original_data/BOOM Sounds/P{id_}Death.wav", f"boomgame/data/sound/Player{id_}Removing.wav")
    copy(f"original_data/BOOM Sounds/P{id_}Complete.wav", f"boomgame/data/sound/Player{id_}Success.wav")

# %%
# Flash

copy("original_data/BOOM Sounds/Teleport.wav", "boomgame/data/sound/FlashSpawn.wav")

# %%
# Bonus

copy("original_data/BOOM Sounds/GetBonus.wav", "boomgame/data/sound/BonusNoise.wav")

# %%
# Extra Letters

copy("original_data/BOOM Sounds/GetLetter.wav", "boomgame/data/sound/ExtraLetterNoise.wav")

# %%
# Maze Sound

copy("original_data/BOOM Sounds/GameOver.wav", "boomgame/data/sound/MazeFailed.wav")
copy("original_data/BOOM Sounds/CompleteLevel.wav", "boomgame/data/sound/MazeSolved.wav")
copy("original_data/BOOM Sounds/EXTRAGame.wav", "boomgame/data/sound/ExtraGame.wav")
copy("original_data/BOOM Sounds/HurryUp.wav", "boomgame/data/sound/HurryUp.wav")
copy("original_data/BOOM Sounds/ExtraLife.wav", "boomgame/data/sound/ExtraLife.wav")

# %% [markdown]
# ###  Levels and maze

# %%
import json
import xml.etree.ElementTree as ET

import boomgame.model.entity

# %%
players = {
    "X": 1,
    "Y": 2,
}

klasses = {
    "1": boomgame.model.entity.SolidWall,
    "2": boomgame.model.entity.BreakableWall,
    "3": boomgame.model.entity.Coin,
    "A": boomgame.model.entity.Soldier,
    "B": boomgame.model.entity.Sarge,
    "C": boomgame.model.entity.Lizzy,
    "D": boomgame.model.entity.Taur,
    "E": boomgame.model.entity.Gunner,
    "F": boomgame.model.entity.Thing,
    "G": boomgame.model.entity.Ghost,
    "H": boomgame.model.entity.Smoulder,
    "I": boomgame.model.entity.Skully,
    "J": boomgame.model.entity.Giggler,
    "*": boomgame.model.entity.Head,  # not valid for level 80
    "+": boomgame.model.entity.Teleporter,
}

undecoded = set()


def parse_repr(maze_repr):
    """From original to actual"""
    maze = boomgame.model.maze.Maze((13, 15))
    for n, c in enumerate(maze_repr):
        if c == "0":
            continue
        i = n // 15
        j = n % 15
        if c in players:
            maze.player_spawns[players[c]] = boomgame.model.vector.Vector((float(i), float(j)))
            continue

        klass = klasses.get(c)
        if not klass:
            print(f"Undecoded '{c}' at ({i}, {j})")
            undecoded.add(c)
            continue

        maze.add_entity(klass(maze, boomgame.model.vector.Vector((float(i), float(j)))))

    return maze

# %%
def parse_xml(level_xml):
    level = {}

    key = None
    for child in level_xml:
        if child.tag == "key":
            assert key is None
            key = child.text
        else:
            value = child.text
            if child.tag == "integer":
                value = int(value)
            assert key is not None
            level[key] = value
            key = None

    return level

# %%
tree = ET.parse("original_data/BOOM Levels.xml")
root = tree.getroot()
levels = root.find("dict").find("array")

game = []

for i, level_xml in enumerate(levels):
    print("======================")
    print(i)
    level = parse_xml(level_xml)
    meta_data = {
        "style": i // 10,
        "maze_id": i + 1,
        "time": level["Time"],
    }

    maze = parse_repr(level["GridDescString"])
    print(maze)
    maze.save(f"boomgame/data/maze/{meta_data['maze_id']}.txt")
    game.append(meta_data)

print("Undecoded chars:")
print(undecoded)
with open("boomgame/data/game/boom.json", "w") as f:
    json.dump(game, f, indent=True)
